# %% [markdown]
# # Explore here

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv')
df.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# ...

# %%
# Basic information
print(df.shape)         # Dimensions of the dataset
print(df.info())        # Data types and non-null values
# Out:
# (3140, 108)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB
# None

# %%
df.describe()    # Summary statistics for numerical columns
# Out:
#                fips       TOT_POP           0-9  0-9 y/o % of total pop  \
# count   3140.000000  3.140000e+03  3.140000e+03             3140.000000
# mean   30401.640764  1.041894e+05  1.274030e+04               11.871051
# std    15150.559265  3.335834e+05  4.180730e+04                2.124081
# min     1001.000000  8.800000e+01  0.000000e+00                0.000000
# 25%    18180.500000  1.096325e+04  1.280500e+03               10.594639
# 50%    29178.000000  2.580050e+04  3.057000e+03               11.802727
# 75%    45081.500000  6.791300e+04  8.097000e+03               12.951840
# max    56045.000000  1.010552e+07  1.208253e+06               25.460677
#
#              19-Oct  10-19 y/o % of total pop         20-29  \
# count  3.140000e+03               3140.000000  3.140000e+03
# mean   1.336798e+04                 12.694609  1.446933e+04
# std    4.228439e+04                  1.815044  4.957773e+04
# min    0.000000e+00                  0.000000  0.000000e+00
# ...

# %%
print(df.columns) # List of column names
# Out:
# Index(['fips', 'TOT_POP', '0-9', '0-9 y/o % of total pop', '19-Oct',
#        '10-19 y/o % of total pop', '20-29', '20-29 y/o % of total pop',
#        '30-39', '30-39 y/o % of total pop',
#        ...
#        'COPD_number', 'diabetes_prevalence', 'diabetes_Lower 95% CI',
#        'diabetes_Upper 95% CI', 'diabetes_number', 'CKD_prevalence',
#        'CKD_Lower 95% CI', 'CKD_Upper 95% CI', 'CKD_number',
#        'Urban_rural_code'],
#       dtype='object', length=108)

# %%
print(list(df))  # List of column names
# Out:
# ['fips', 'TOT_POP', '0-9', '0-9 y/o % of total pop', '19-Oct', '10-19 y/o % of total pop', '20-29', '20-29 y/o % of total pop', '30-39', '30-39 y/o % of total pop', '40-49', '40-49 y/o % of total pop', '50-59', '50-59 y/o % of total pop', '60-69', '60-69 y/o % of total pop', '70-79', '70-79 y/o % of total pop', '80+', '80+ y/o % of total pop', 'White-alone pop', '% White-alone', 'Black-alone pop', '% Black-alone', 'Native American/American Indian-alone pop', '% NA/AI-alone', 'Asian-alone pop', '% Asian-alone', 'Hawaiian/Pacific Islander-alone pop', '% Hawaiian/PI-alone', 'Two or more races pop', '% Two or more races', 'POP_ESTIMATE_2018', 'N_POP_CHG_2018', 'GQ_ESTIMATES_2018', 'R_birth_2018', 'R_death_2018', 'R_NATURAL_INC_2018', 'R_INTERNATIONAL_MIG_2018', 'R_DOMESTIC_MIG_2018', 'R_NET_MIG_2018', 'Less than a high school diploma 2014-18', 'High school diploma only 2014-18', "Some college or associate's degree 2014-18", "Bachelor's degree or higher 2014-18", 'Percent of adults with l
# ...

# %%
# Find total number of missing values each column left
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# fips                      0
# TOT_POP                   0
# 0-9                       0
# 0-9 y/o % of total pop    0
# 19-Oct                    0
#                          ..
# CKD_prevalence            0
# CKD_Lower 95% CI          0
# CKD_Upper 95% CI          0
# CKD_number                0
# Urban_rural_code          0
# Length: 108, dtype: int64

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
#Remove duplicate rows and show new shape 
df = df.drop_duplicates()
print(f"Shape after removing duplicates: {df.shape}")
# Out:
# Shape after removing duplicates: (3140, 108)

# %%
# Define target variable
target_variable = 'Obesity_prevalence'

# %%
df.Obesity_prevalence
# Out:
# 0       35.8
# 1       29.7
# 2       40.7
# 3       38.7
# 4       34.0
#         ...
# 3135    33.6
# 3136    19.4
# 3137    34.2
# 3138    28.4
# 3139    34.4
# Name: Obesity_prevalence, Length: 3140, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution of the target variable
plt.figure(figsize=(8, 6))
sns.histplot(df[target_variable], kde=True)
plt.title(f'Distribution of {target_variable}')
plt.show()

# %%
# Campaign contacts ("campaign")
sns.histplot(df['anycondition_prevalence'], bins=30, kde=True, color='green')
plt.xticks(rotation=45)
plt.title('anycondition_prevalence Distribution')
plt.show()

# %%
# Campaign contacts ("campaign")
sns.histplot(df['anycondition_prevalence'], bins=30, kde=True, color='green')
plt.xticks(rotation=45)
plt.title('Anycondition Prevalence Distribution')
plt.show()

# %%
# Marital status
sns.histplot(df['Heart disease_prevalence'], bins=30, kde=True, color='red')
plt.xticks(rotation=45)
plt.title('Heart disease_prevalence Distribution')
plt.show()

# %%
# Education
sns.histplot(df['COPD_prevalence'], bins=30, kde=True, color='blue')
plt.xticks(rotation=45)
plt.title('COPD_prevalence Distribution')
plt.show()

# %%
# Marital status
sns.histplot(df['Employed_2018'], bins=30, color='red')
plt.xticks(rotation=45)
plt.title('Employed_2018 Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numerical features


numerical_features = df.select_dtypes(include=['number']).columns.tolist()


for columns in numerical_features:
    print(columns)
# Out:
# fips
# TOT_POP
# 0-9
# 0-9 y/o % of total pop
# 19-Oct
# 10-19 y/o % of total pop
# 20-29
# 20-29 y/o % of total pop
# 30-39
# 30-39 y/o % of total pop
# 40-49
# 40-49 y/o % of total pop
# 50-59
# 50-59 y/o % of total pop
# 60-69
# 60-69 y/o % of total pop
# 70-79
# 70-79 y/o % of total pop
# 80+
# 80+ y/o % of total pop
# White-alone pop
# % White-alone
# Black-alone pop
# % Black-alone
# Native American/American Indian-alone pop
# % NA/AI-alone
# Asian-alone pop
# % Asian-alone
# Hawaiian/Pacific Islander-alone pop
# % Hawaiian/PI-alone
# Two or more races pop
# % Two or more races
# POP_ESTIMATE_2018
# N_POP_CHG_2018
# GQ_ESTIMATES_2018
# R_birth_2018
# R_death_2018
# R_NATURAL_INC_2018
# R_INTERNATIONAL_MIG_2018
# R_DOMESTIC_MIG_2018
# R_NET_MIG_2018
# Less than a high school diploma 2014-18
# High school diploma only 2014-18
# Some college or associate's degree 2014-18
# Bachelor's degree or higher 2014-18
# Percent of adults with less than a high school diploma 2014-18
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axis = plt.subplots(4, 2, figsize = (10, 10), gridspec_kw={'height_ratios': [6, 1, 6, 1]})

# Creating a multiple figure with histograms and box plots
sns.histplot(ax = axis[0, 0], data = df, x = "anycondition_prevalence").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = df, x = "anycondition_prevalence")
sns.histplot(ax = axis[0, 1], data = df, x = "Obesity_prevalence").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = df, x = "Obesity_prevalence")
sns.histplot(ax = axis[2, 0], data = df, x = "Heart disease_prevalence").set(xlabel = 'Consumer Confidence Index')
sns.boxplot(ax = axis[3, 0], data = df, x = "Heart disease_prevalence")
sns.histplot(ax = axis[2, 1], data = df, x = "diabetes_prevalence").set(xlabel = 'number of employees', ylabel = None)
sns.boxplot(ax = axis[3, 1], data = df, x = "diabetes_prevalence")

plt.suptitle("Numerical Variable Analysis")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a heatmap
sns.heatmap(df[numerical_features].corr(), annot = True, fmt = ".2f")
plt.title("Correlation Matrix of Numerical Features", y=1.02)
plt.show()

# %%
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
# dropping columns we dont need
df = df.drop(["fips"], axis=1)
df
# Out:
#       TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0       55601   6787               12.206615    7637
# 1      218022  24757               11.355276   26913
# 2       24881   2732               10.980266    2960
# 3       22400   2456               10.964286    2596
# 4       57840   7095               12.266598    7570
# ...       ...    ...                     ...     ...
# 3135    43051   6104               14.178532    6326
# 3136    23081   2384               10.328842    2185
# 3137    20299   3121               15.375142    3205
# 3138     7885    858               10.881420    1113
# 3139     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# 2                    11.896628   3268                 13.134520   3201
# ...

# %%
# Calculate the total number of missing values for each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# TOT_POP                     0
# 0-9                         0
# 0-9 y/o % of total pop      0
# 19-Oct                      0
# 10-19 y/o % of total pop    0
#                            ..
# CKD_prevalence              0
# CKD_Lower 95% CI            0
# CKD_Upper 95% CI            0
# CKD_number                  0
# Urban_rural_code            0
# Length: 107, dtype: int64

# %%
# Percentage of missing values
missing_percentages = (df.isnull().mean() * 100)
print(missing_percentages)
# Out:
# TOT_POP                     0.0
# 0-9                         0.0
# 0-9 y/o % of total pop      0.0
# 19-Oct                      0.0
# 10-19 y/o % of total pop    0.0
#                            ...
# CKD_prevalence              0.0
# CKD_Lower 95% CI            0.0
# CKD_Upper 95% CI            0.0
# CKD_number                  0.0
# Urban_rural_code            0.0
# Length: 107, dtype: float64

# %%
# Define the threshold (e.g., 30%)
threshold = 30

# Drop columns where the percentage of missing values exceeds the threshold
columns_to_drop = missing_percentages[missing_percentages > threshold].index

# Drop those columns from the dataframe
df = df.drop(columns=columns_to_drop)

print(f"Following columns were dropped: {list(columns_to_drop)}")
# Out:
# Following columns were dropped: []

# %%
categorical_features = ['job', 'marital', 'education', 'loan']

fig, axis = plt.subplots(2, 2, figsize = (10, 7))

# Creating a multiple figure with histograms and box plots
sns.histplot(ax = axis[0, 0], data = df, x = "job")
sns.histplot(ax = axis[1, 0], data = df, x = "marital")
sns.histplot(ax = axis[0, 1], data = df, x = "education")
sns.histplot(ax = axis[1, 1], data = df, x = "loan")


plt.suptitle("Categorical Variable Analysis")
plt.tight_layout()

# Show the plot
plt.show()
